# %% [markdown]
# <a href="https://colab.research.google.com/github/Ale-cipriano/Ale-cipriano/blob/main/Baires_Redu%C3%A7%C3%A3o_Dimensionalidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open('/content/Lenna.png')
plt.imshow(image)
plt.show()

# %%
gray_image = image.convert('L')
plt.imshow(gray_image, cmap='gray')
plt.show()

# %%
treshold = 128
binary_image = gray_image.point(lambda x: 0 if x < treshold else 255, '1')
plt.imshow(binary_image, cmap='gray')
plt.show()
